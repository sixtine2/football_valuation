# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../data/chaff_stats.csv')

# %%
liste = df['pretty_name']

# %%
list(liste)
# Out:
# ['James Milner',
#  'Zlatan Ibrahimovic',
#  'Ricardo Quaresma',
#  'Maarten Stekelenburg',
#  'Francesco Magnanelli',
#  'Jonas Hofmann',
#  'Pepe Reina',
#  'Cristiano Ronaldo',
#  'Philipp Pentke',
#  'Rui Fonte',
#  'Daley Blind',
#  'Niki Maenpaa',
#  'Goran Pandev',
#  'Ben Foster',
#  'Ashley Young',
#  'Aaron Lennon',
#  'Raul Albiol',
#  'Jesus Navas',
#  'Edgar Barreto',
#  'Casemiro',
#  'Kasper Schmeichel',
#  'Kevin Prince Boateng',
#  'Manuel Neuer',
#  'Hugo Lloris',
#  'Alvaro Negredo',
#  'Jimmy Briand',
#  'Karim Benzema',
#  'Thomas Mangani',
#  'Gerard Pique',
#  'Willem Janssen',
#  'Corentin Jean',
#  'Andres Guardado',
#  'Federico Peluso',
#  'Gianluca Pegolo',
#  'Valon Behrami',
#  'Cristian Molinaro',
#  'Franck Ribery',
#  'Fabio Quagliarella',
#  'Benoit Costil',
#  'Lennart Thy',
#  'Steve Mandanda',
#  'Jeremy Morel',
#  'Romain Salin',
#  'Jacob Mulenga',
#  'Antonio Candreva',
#  'Salvatore Sirigu',
#  'Remko Pasveer',
#  'Sergio Ramos',
# ...

# %%
url = "https://raw.githubusercontent.com/sixtine2/football_valuation/master/data/final_data_v1.csv"
df = pd.read_csv(url, sep = ';')
df.columns
# Out:
# Index(['Unnamed: 0', 'player_id', 'pretty_name', 'age', 'height_cm',
#        'weight_kg', 'foot', 'Nationality', 'club_name',
#        'club_contract_valid_until', 'release_clause_eur', 'position',
#        'Minutes played', 'Goals', 'Assists', 'Yellow cards', 'Red cards',
#        'SpG', 'PS%', 'Aearials Won', 'MotM', 'Rating', 'Tackles',
#        'Interceptions', 'Fouls commited', 'Clearances', 'Dribbled past',
#        'Blocks', 'Key Passes', 'Dribbles', 'Fouled', 'Dispossessed',
#        'Bad control', 'Crosses', 'Long balls', 'Through balls', 'Games',
#        'market_value_in_eur', 'missed_games', 'wiki_views', 'insta_followers',
#        'Play_in_CL', 'player_face_url', 'club_logo_url', 'club_flag_url',
#        'nation_logo_url', 'nation_flag_url', 'player_positions', 'overall',
#        'potential', 'wage_eur'],
#       dtype='object')

# %%
df[['Aearials Won', 'MotM', 'Rating', 'Tackles',
       'Interceptions', 'Fouls commited', 'Clearances', 'Dribbled past',
       'Blocks']][df['position'] == 'Goalkeeper']
# Out:
#       Aearials Won  MotM  Rating  Tackles  Interceptions  Fouls commited  \
# 3             0.10     1    6.73     0.00           0.14            0.00
# 6             0.27     1    6.45     0.00           0.03            0.05
# 8             0.54     0    6.96     0.00           0.00            0.00
# 11            0.42     0    6.29     0.00           0.00            0.12
# 13            0.26     2    6.55     0.00           0.00            0.05
# ...            ...   ...     ...      ...            ...             ...
# 2517          0.44     2    6.66     0.00           0.08            0.00
# 2546          0.00     1    6.46     0.00           0.10            0.10
# 2619          0.50     0    6.50     0.00           0.00            0.00
# 2621          0.10     0    6.52     0.06           0.06            0.18
# 2626          0.30     1    6.61     0.00           0.00            0.05
#
#       Clearances  Dribbled past  Blocks
# 3           0.43           0.00     0.0
# ...
