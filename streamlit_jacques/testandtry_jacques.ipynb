# %%
# $DELETE_BEGIN
from datetime import datetime
import pytz

import pandas as pd
import joblib

from fastapi import FastAPI
from fastapi.middleware.cors import CORSMiddleware

app = FastAPI()

app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],  # Allows all origins
    allow_credentials=True,
    allow_methods=["*"],  # Allows all methods
    allow_headers=["*"],  # Allows all headers
)

# http://127.0.0.1:8000/predict?pickup_datetime=2012-10-06 12:10:20&pickup_longitude=40.7614327&pickup_latitude=-73.9798156&dropoff_longitude=40.6513111&dropoff_latitude=-73.8803331&passenger_count=2

@app.get("/")
def index():
    return dict(greeting="startfootball_visalisation")

# %%
# run_api:
# !uvicorn api.fast:app --reload  # load web server with code autoreload
# Out:
# INFO:     Will watch for changes in these directories: ['/home/jacques/code/football_valuation/streamlit_jacques']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [7512] using statreload
# INFO:     Started server process [7514]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     127.0.0.1:59618 - "GET / HTTP/1.1" 200 OK
# WARNING:  StatReload detected file change in 'api/fast.py'. Reloading...
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [7514]
# INFO:     Started server process [7550]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     127.0.0.1:59620 - "GET / HTTP/1.1" 200 OK
# WARNING:  StatReload detected file change in 'api/fast.py'. Reloading...
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [7550]
# Process SpawnProcess-3:
# Traceback (most recent call last):
#   File "/home/jacques/.pyenv/versions/3.8.12/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/jacques/.pyenv/versions/3.8.12/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/jacques/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/uvicorn/subprocess.py", line 76, in subprocess_started
#     target(sockets=sockets)
#   File "/home/jacques/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/uvicorn/server.py", line 68, in run
#     return asyncio.run(self.serve(sockets=sockets))
#   File "/home/jacques/.pyenv/versions/3.8.12/lib/python3.8/asyncio/runners.py", line 44, in run
#     return loop.run_until_complete(main)
#   File "/home/jacques/.pyenv/versions/3.8.12/lib/python3.8/asyncio/base_events.py", line 616, in run_until_complete
#     return future.result()
#   File "/home/jacques/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/uvicorn/server.py", line 76, in serve
#     config.load()
#   File "/home/jacques/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/uvicorn/config.py", line 456, in load
#     self.loaded_app = import_from_string(self.app)
#   File "/home/jacques/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/uvicorn/importer.py", line 21, in import_from_string
#     module = importlib.import_module(module_str)
#   File "/home/jacques/.pyenv/versions/3.8.12/lib/python3.8/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1014, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 839, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 976, in get_code
#   File "<frozen importlib._bootstrap_external>", line 906, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/jacques/code/football_valuation/streamlit_jacques/./api/fast.py", line 42
#     X = (player_name))
#                      ^
# SyntaxError: unmatched ')'
# INFO:     Stopping reloader process [7512]

# %% [markdown]
# # Get data from github repo

# %%
import pandas as pd

import requests
from pprint import pprint

# github username
username = "x4nth055"
# url to request
url = f"https://api.github.com/users/{username}"
# make the request and return the json
user_data = requests.get(url).json()
# pretty print JSON data
pprint(user_data)
# Out:
# {'avatar_url': 'https://avatars.githubusercontent.com/u/37851086?v=4',
#  'bio': None,
#  'blog': 'https://www.thepythoncode.com',
#  'company': None,
#  'created_at': '2018-03-27T21:49:04Z',
#  'email': None,
#  'events_url': 'https://api.github.com/users/x4nth055/events{/privacy}',
#  'followers': 380,
#  'followers_url': 'https://api.github.com/users/x4nth055/followers',
#  'following': 41,
#  'following_url': 'https://api.github.com/users/x4nth055/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/x4nth055/gists{/gist_id}',
#  'gravatar_id': '',
#  'hireable': True,
#  'html_url': 'https://github.com/x4nth055',
#  'id': 37851086,
#  'location': 'Algeria',
#  'login': 'x4nth055',
#  'name': 'Rockikz',
#  'node_id': 'MDQ6VXNlcjM3ODUxMDg2',
#  'organizations_url': 'https://api.github.com/users/x4nth055/orgs',
#  'public_gists': 0,
#  'public_repos': 12,
#  'received_events_url': 'https://api.github.com/users/x4nth055/received_events',
#  'repos_url': 'https://api.github.com/users/x4nth055/repos',
#  'site_admin': False,
#  'starred_url': 'https://api.github.com/users/x4nth055/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/x4nth055/subscriptions',
#  'twitter_username': None,
#  'type': 'User',
#  'updated_at': '2021-08-11T11:33:48Z',
#  'url': 'https://api.github.com/users/x4nth055'}

# %%
import pandas as pd

import requests
from pprint import pprint

# github username
username = "x4nth055"
# url to request
url = f"https://api.github.com/users/{username}"
# make the request and return the json
user_data = requests.get(url).json()
# pretty print JSON data
pprint(user_data)
# Out:
# {'avatar_url': 'https://avatars.githubusercontent.com/u/37851086?v=4',
#  'bio': None,
#  'blog': 'https://www.thepythoncode.com',
#  'company': None,
#  'created_at': '2018-03-27T21:49:04Z',
#  'email': None,
#  'events_url': 'https://api.github.com/users/x4nth055/events{/privacy}',
#  'followers': 380,
#  'followers_url': 'https://api.github.com/users/x4nth055/followers',
#  'following': 41,
#  'following_url': 'https://api.github.com/users/x4nth055/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/x4nth055/gists{/gist_id}',
#  'gravatar_id': '',
#  'hireable': True,
#  'html_url': 'https://github.com/x4nth055',
#  'id': 37851086,
#  'location': 'Algeria',
#  'login': 'x4nth055',
#  'name': 'Rockikz',
#  'node_id': 'MDQ6VXNlcjM3ODUxMDg2',
#  'organizations_url': 'https://api.github.com/users/x4nth055/orgs',
#  'public_gists': 0,
#  'public_repos': 12,
#  'received_events_url': 'https://api.github.com/users/x4nth055/received_events',
#  'repos_url': 'https://api.github.com/users/x4nth055/repos',
#  'site_admin': False,
#  'starred_url': 'https://api.github.com/users/x4nth055/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/x4nth055/subscriptions',
#  'twitter_username': None,
#  'type': 'User',
#  'updated_at': '2021-08-11T11:33:48Z',
#  'url': 'https://api.github.com/users/x4nth055'}
